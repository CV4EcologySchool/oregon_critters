# %%
import pandas as pd
import os
import shutil
from tqdm import tqdm

# %%
#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/sampled_ds_bothA_350_split.csv')
#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/sampled_ds_ground_620.csv')
#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/sampled_ds_trail_180.csv')

#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/ground_split.csv')
df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/trail_split.csv')

df.head()
# Out:
#    Unnamed: 0                                     full_path_orig  LID  \
# 0           1  data/COA_2019/hailey.hester-COA2019_Coyote/ima...    1
# 1           2  data/COA_2019/hailey.hester-COA2019_Coyote/ima...    2
# 2           3  data/COA_2019/hailey.hester-COA2019_Coyote/ima...    3
# 3           4  data/COA_2019/COA2019_Bat/images/10316-5__2019...    4
# 4           5  data/COA_2019/COA2019_Bat/images/10831-1__2019...   15
#
#           CName            X            Y            W           H  \
# 0        Coyote     2.487805   967.756098   440.341463  681.658537
# 1        Coyote     2.487805   853.317073   440.341463  728.926829
# 2        Coyote     4.975610   816.000000   420.439024  738.878049
# 3           Bat  1414.630021  1792.900518   824.016913  425.915281
# 4  RooseveltElk   294.291755  1784.787846  1359.830867  965.407971
#
#                                   IName  \
# 0  10022-4__2019-07-30__08-43-18(1).JPG
# 1  10022-4__2019-07-30__08-43-19(2).JPG
# 2  10022-4__2019-07-30__08-43-19(3).JPG
# 3  10316-5__2019-08-05__04-43-55(1).JPG
# 4  10831-1__2019-08-07__01-08-48(7).JPG
#
#                                     file_path  ...     site  \
# 0  data/COA_2019/hailey.hester-COA2019_Coyote  ...  10022-4
# 1  data/COA_2019/hailey.hester-COA2019_Coyote  ...  10022-4
# 2  data/COA_2019/hailey.hester-COA2019_Coyote  ...  10022-4
# 3                   data/COA_2019/COA2019_Bat  ...  10316-5
# 4                   data/COA_2019/COA2019_Bat  ...  10831-1
#
#               datetime cam_type day_night  year remove  \
# 0  2019-07-30 08:43:18        T     night  2019   keep
# 1  2019-07-30 08:43:19        T     night  2019   keep
# 2  2019-07-30 08:43:19        T     night  2019   keep
# 3  2019-08-05 04:43:55        T     night  2019   keep
# 4  2019-08-07 01:08:48        T     night  2019   keep
#
#                                            full_path        stn sequence_id  \
# 0  data/COA_2019/hailey.hester-COA2019_Coyote/ima...  10022-4-T         103
# 1  data/COA_2019/hailey.hester-COA2019_Coyote/ima...  10022-4-T         103
# 2  data/COA_2019/hailey.hester-COA2019_Coyote/ima...  10022-4-T         103
# 3  data/COA_2019/COA2019_Bat/images/10316-5__2019...  10316-5-T        2093
# 4  data/COA_2019/COA2019_Bat/images/10831-1__2019...  10831-1-T        5462
#
#    group
# 0  train
# 1  train
# 2  train
# 3   test
# 4   test
#
# [5 rows x 25 columns]

# %%
df['full_path'].values
# Out:
# array(['data/COA_2019/hailey.hester-COA2019_Coyote/images/10022-4__2019-07-30__08-43-18(1)_hx.JPG',
#        'data/COA_2019/hailey.hester-COA2019_Coyote/images/10022-4__2019-07-30__08-43-19(2)_hx.JPG',
#        'data/COA_2019/hailey.hester-COA2019_Coyote/images/10022-4__2019-07-30__08-43-19(3)_hx.JPG',
#        ...,
#        'data/HJA_MARIE/hailey.hester-HJA_MARIE_Dog/images/SM-PG_2018-11-14_IMG_0197_ch.JPG',
#        'data/HJA_MARIE/hailey.hester-HJA_MARIE_Dog/images/SM-PG_2018-11-14_IMG_0198_ch.JPG',
#        'data/HJA_MARIE/hailey.hester-HJA_MARIE_Dog/images/SM-PG_2018-11-14_IMG_0199_ch.JPG'],
#       dtype=object)

# %%
for file in tqdm(df['full_path'].values):
    
    file_source = '/Users/caraappel/Documents/CV4E/' + file
    #file_target = '/Users/caraappel/Documents/CV4E/upload_trail_thresh180/' + file
    file_target = '/Volumes/Cara_cam_traps/CV4E/data_cleaned/trail/' + file

    os.makedirs(os.path.dirname(file_target), exist_ok=True)

    shutil.copy(file_source, file_target)
# Out:
# 100%|██████████| 62572/62572 [21:08<00:00, 49.31it/s]
