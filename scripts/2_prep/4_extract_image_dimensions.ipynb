# %%
## Extract image dimensions and add to CSV

from PIL import Image
import os
import pandas as pd

# Read in CSV
#input_path = '/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/empty/empty_split_esftrail.csv' 
input_path = '/Volumes/Cara_cam_traps/CV4E/data_cleaned/demo2/demo2_empties.csv'
dataframe = pd.read_csv(input_path)

# %%
dataframe['destination_path'].values

# %%
dataframe['Full Path'].values

# %%
#preview (check correct column name here)
# dataframe['Full Path'].values

#edit/create new column for COA files since these were done on an external hard drive. I just want to point to the ones I've curated that are stored locally.
dataframe['source_path'] = '/Users/caraappel/Documents/CV4E/data/empty_photos/subsets_1000/COA_2020/' + dataframe['filename']
dataframe['source_path'].values

# %%
# Define function to get image dimensions
def get_image_dimensions(filename):
    with Image.open(filename) as img:
        return img.size

# %%
# Create lists to store dim
width_output = []
height_output = []

# Extract dimensions
for image in dataframe['Full Path'].values:
    width, height = get_image_dimensions(image)
    width_output.append(width)
    height_output.append(height)
    
# Append to CSV
dataframe['img_width'] = width_output
dataframe['img_height'] = height_output

dataframe.head()
# Out:
#    Unnamed: 0   V1                Filename       site image  \
# 0           1  873     DUNE5A_IMG_0906.JPG     DUNE5A   IMG
# 1           2  422  DUNE4-96B_IMG_0307.JPG  DUNE4-96B   IMG
# 2           3  639  DUNE4-96B_IMG_3614.JPG  DUNE4-96B   IMG
# 3           4  228    18809D_bait_0029.JPG     18809D  bait
# 4           5  372    18908G_bait_0164.JPG     18908G  bait
#
#                                            Full Path        Creation Date  \
# 0  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021:08:15 22:04:32
# 1  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021:09:19 20:28:47
# 2  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021:11:22 03:36:24
# 3  /Users/caraappel/Documents/CV4E/data/empty_pho...  2022:09:07 18:36:12
# 4  /Users/caraappel/Documents/CV4E/data/empty_pho...  2022:08:19 16:48:55
#
#                                     destination_path             datetime  \
# 0  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021-08-15 22:04:32
# 1  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021-09-19 20:28:47
# 2  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021-11-22 03:36:24
# 3  /Users/caraappel/Documents/CV4E/data/empty_pho...  2022-09-07 18:36:12
# 4  /Users/caraappel/Documents/CV4E/data/empty_pho...  2022-08-19 16:48:55
#
#          stn  sequence_id  group   project  model  \
# 0     DUNE5A          455  train     DUNES  trail
# 1  DUNE4-96B          198  train     DUNES  trail
# 2  DUNE4-96B          333  train     DUNES  trail
# 3     18809D           74  train  ESF_BAIT  trail
# 4     18908G          122  train  ESF_BAIT  trail
#
#                                                 path  \
# 0  data/DUNES/DUNES_empty/images/DUNE5A_IMG_0906.JPG
# 1  data/DUNES/DUNES_empty/images/DUNE4-96B_IMG_03...
# 2  data/DUNES/DUNES_empty/images/DUNE4-96B_IMG_36...
# 3  data/ESF_BAIT/ESF_BAIT_empty/images/18809D_bai...
# 4  data/ESF_BAIT/ESF_BAIT_empty/images/18908G_bai...
#
#                                            full_path  img_width  img_height
# 0       DUNES/DUNES_empty/images/DUNE5A_IMG_0906.JPG       3840        2160
# 1    DUNES/DUNES_empty/images/DUNE4-96B_IMG_0307.JPG       1920        1080
# 2    DUNES/DUNES_empty/images/DUNE4-96B_IMG_3614.JPG       1920        1080
# 3  ESF_BAIT/ESF_BAIT_empty/images/18809D_bait_002...       1920        1080
# 4  ESF_BAIT/ESF_BAIT_empty/images/18908G_bait_016...       1920        1080

# %%
# Save new CSV
output_path = input_path.replace('.csv', '_dim.csv')
dataframe.to_csv(output_path)

print('saved file' + output_path)
# Out:
# saved file/Volumes/Cara_cam_traps/CV4E/data_cleaned/demo2/demo2_empties_dim.csv

# %%
## one-time thing: append 'demo2_empties_dim' rows with 'demo2.csv'
##(will I need to do this with the full dataset? both.csv, ground.csv, trail.csv)

#read in demo2_empties_dim or assign from above
demo2_empties = dataframe

#read in demo2.csv
orig_csv = '/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/demo2.csv'
orig_df = pd.read_csv(orig_csv)

#fix any column names for matching
demo2_empties['folder'] = 'empty'
demo2_empties['full_path'] = 'data/' + demo2_empties['full_path']
demo2_empties['image_name'] = demo2_empties['Filename']

#bind with original
col_to_keep = ['project','folder','image_name','site','stn','datetime','full_path','sequence_id','group','img_width','img_height']
orig_df_dim = pd.concat([orig_df, demo2_empties[col_to_keep]], axis=0, join='outer', ignore_index=True)

orig_df_dim.head

## Save
orig_df_dim.to_csv('/Volumes/Cara_cam_traps/CV4E/data_cleaned/demo2/demo2_with_empties.csv', index=False)
orig_df_dim.to_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/demo2_with_empties.csv', index=False)
