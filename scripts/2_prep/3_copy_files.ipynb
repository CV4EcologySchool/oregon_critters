# %%
import pandas as pd
import os
import shutil
from tqdm import tqdm

# %%
#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/sampled_ds_bothA_350_split.csv')
#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/sampled_ds_ground_620.csv')
#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/sampled_ds_trail_180.csv')

#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/ground_split.csv')
#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/trail_split.csv')
#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/both_split.csv')

#df = pd.read_csv('/Users/caraappel/Documents/CV4E/oregon_critters/metadata_labels/demo2.csv')
df = pd.read_csv('/Volumes/Cara_cam_traps/CV4E/data_cleaned/demo2/demo2_empties.csv')

df.head()
# Out:
#    Unnamed: 0   V1                Filename       site image  \
# 0           1  873     DUNE5A_IMG_0906.JPG     DUNE5A   IMG
# 1           2  422  DUNE4-96B_IMG_0307.JPG  DUNE4-96B   IMG
# 2           3  639  DUNE4-96B_IMG_3614.JPG  DUNE4-96B   IMG
# 3           4  228    18809D_bait_0029.JPG     18809D  bait
# 4           5  372    18908G_bait_0164.JPG     18908G  bait
#
#                                            Full Path        Creation Date  \
# 0  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021:08:15 22:04:32
# 1  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021:09:19 20:28:47
# 2  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021:11:22 03:36:24
# 3  /Users/caraappel/Documents/CV4E/data/empty_pho...  2022:09:07 18:36:12
# 4  /Users/caraappel/Documents/CV4E/data/empty_pho...  2022:08:19 16:48:55
#
#                                     destination_path             datetime  \
# 0  /Users/caraappel/Documents/CV4E/data/empty_pho...  2021-08-15 22:04:32
# ...

# %%
df['full_path'].values
df['Full Path'].values #for empties
# Out:
# array(['/Users/caraappel/Documents/CV4E/data/empty_photos/full/DUNES_FULL/NONE/DUNE5A_IMG_0906.JPG',
#        '/Users/caraappel/Documents/CV4E/data/empty_photos/full/DUNES_FULL/NONE/DUNE4-96B_IMG_0307.JPG',
#        '/Users/caraappel/Documents/CV4E/data/empty_photos/full/DUNES_FULL/NONE/DUNE4-96B_IMG_3614.JPG',
#        '/Users/caraappel/Documents/CV4E/data/empty_photos/full/ESF_BAIT_FULL/NONE/18809D_bait_0029.JPG',
#        '/Users/caraappel/Documents/CV4E/data/empty_photos/full/ESF_BAIT_FULL/NONE/18908G_bait_0164.JPG',
#        '/Users/caraappel/Documents/CV4E/data/empty_photos/full/DUNES_FULL/NONE/DUNE5A_IMG_1181.JPG',
#        '/Users/caraappel/Documents/CV4E/data/empty_photos/full/ESF_TRAIL_FULL/NONE/18807A_trail_0071.JPG',
#        '/Users/caraappel/Documents/CV4E/data/empty_photos/full/ESF_BAIT_FULL/NONE/19007D_bait_0194.JPG',
#        '/Users/caraappel/Documents/CV4E/data/empty_photos/full/ESF_GROUND_FULL/NONE/18909H_small_11996.JPG',
# ...

# %%
for file in tqdm(df['full_path'].values):
    
    #file_source = '/Users/caraappel/Documents/CV4E/' + file
    #file_target = '/Users/caraappel/Documents/CV4E/upload_trail_thresh180/' + file
    #file_target = '/Volumes/Cara_cam_traps/CV4E/data_cleaned/both/' + file

    #for empties:
    file_source = file
    file_target = '/Volumes/Cara_cam_traps/CV4E/data_cleaned/demo2/data/' + file

    os.makedirs(os.path.dirname(file_target), exist_ok=True)

    shutil.copy(file_source, file_target)

# %%
## For empties: (messy but just move them later... ugh)
for file in tqdm(df['Full Path'].values):
    
    file_source = file
    file_target = '/Volumes/Cara_cam_traps/CV4E/data_cleaned/demo2/data/' + file

    os.makedirs(os.path.dirname(file_target), exist_ok=True)

    shutil.copy(file_source, file_target)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 164.85it/s]
